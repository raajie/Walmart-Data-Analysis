# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv(r"C:\Users\Chitra\OneDrive\Documents\ScalerNotes\StatisticalProgramming\CaseStudy\walmart_data.txt")

# %%
df.head()
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
# 2  1000001  P00087842      F  0-17          10             A
# 3  1000001  P00085442      F  0-17          10             A
# 4  1000002  P00285442      M   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category  Purchase
# 0                          2               0                 3      8370
# 1                          2               0                 1     15200
# 2                          2               0                12      1422
# 3                          2               0                12      1057
# 4                         4+               0                 8      7969

# %%
df.isna().sum()
# Out:
# User_ID                       0
# Product_ID                    0
# Gender                        0
# Age                           0
# Occupation                    0
# City_Category                 0
# Stay_In_Current_City_Years    0
# Marital_Status                0
# Product_Category              0
# Purchase                      0
# dtype: int64

# %%
Analysis:
--> No null values in the dataset

# %% [raw]
# Shape and DataTypes with Non-Graphical Analysis:

# %%
row = df.shape[0]
column = df.shape[1]

# %%
print("Row:",row,"Col:",column)
# Out:
# Row: 550068 Col: 10

# %%
Analysis:
Dataset has 550068 rows and 10 columns

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 550068 entries, 0 to 550067
# Data columns (total 10 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   User_ID                     550068 non-null  int64
#  1   Product_ID                  550068 non-null  object
#  2   Gender                      550068 non-null  object
#  3   Age                         550068 non-null  object
#  4   Occupation                  550068 non-null  int64
#  5   City_Category               550068 non-null  object
#  6   Stay_In_Current_City_Years  550068 non-null  object
#  7   Marital_Status              550068 non-null  int64
#  8   Product_Category            550068 non-null  int64
#  9   Purchase                    550068 non-null  int64
# dtypes: int64(5), object(5)
# memory usage: 42.0+ MB

# %%
Analysis:
Dataset has 5 int col and 5 string column

# %%
df.describe()
# Out:
#             User_ID     Occupation  Marital_Status  Product_Category  \
# count  5.500680e+05  550068.000000   550068.000000     550068.000000
# mean   1.003029e+06       8.076707        0.409653          5.404270
# std    1.727592e+03       6.522660        0.491770          3.936211
# min    1.000001e+06       0.000000        0.000000          1.000000
# 25%    1.001516e+06       2.000000        0.000000          1.000000
# 50%    1.003077e+06       7.000000        0.000000          5.000000
# 75%    1.004478e+06      14.000000        1.000000          8.000000
# max    1.006040e+06      20.000000        1.000000         20.000000
#
#             Purchase
# count  550068.000000
# mean     9263.968713
# std      5023.065394
# min        12.000000
# 25%      5823.000000
# 50%      8047.000000
# 75%     12054.000000
# max     23961.000000

# %%
df["User_ID"].nunique()
# Out:
# 5891

# %% [raw]
# No.of Users in the Dataset is 5891

# %%
df["Product_ID"].nunique()
# Out:
# 3631

# %%
df["Marital_Status"].value_counts(normalize=True)
# Out:
# Marital_Status
# 0    0.590347
# 1    0.409653
# Name: proportion, dtype: float64

# %% [raw]
# Analysis:
# --> 60% of customers are Unmarried
# --> 40% are Married

# %%
df["Product_Category"].value_counts()
# Out:
# Product_Category
# 5     150933
# 1     140378
# 8     113925
# 11     24287
# 2      23864
# 6      20466
# 3      20213
# 4      11753
# 16      9828
# 15      6290
# 13      5549
# 10      5125
# 12      3947
# 7       3721
# 18      3125
# 20      2550
# 19      1603
# 14      1523
# 17       578
# 9        410
# Name: count, dtype: int64

# %%
df["Product_Category"].nunique()
# Out:
# 20

# %%
df["Product_Category"].value_counts()
# Out:
# Product_Category
# 5     150933
# 1     140378
# 8     113925
# 11     24287
# 2      23864
# 6      20466
# 3      20213
# 4      11753
# 16      9828
# 15      6290
# 13      5549
# 10      5125
# 12      3947
# 7       3721
# 18      3125
# 20      2550
# 19      1603
# 14      1523
# 17       578
# 9        410
# Name: count, dtype: int64

# %% [raw]
# Analysis:
# -->Dataset has 20 different Product Category
# -->5th category is the highest

# %%
df["Age"].value_counts()
# Out:
# Age
# 26-35    219587
# 36-45    110013
# 18-25     99660
# 46-50     45701
# 51-55     38501
# 55+       21504
# 0-17      15102
# Name: count, dtype: int64

# %%
Analysis:
Age group of Customers between 26-35 is the hightest

# %%
df["Gender"].value_counts(normalize=True)
# Out:
# Gender
# M    0.753105
# F    0.246895
# Name: proportion, dtype: float64

# %% [raw]
# Analysis:
# 75% of customers are Male

# %%
df["City_Category"].value_counts()
# Out:
# City_Category
# B    231173
# C    171175
# A    147720
# Name: count, dtype: int64

# %% [raw]
# Analysis:
# Customers are from 3 different cities

# %%
df["Occupation"].value_counts()
# Out:
# Occupation
# 4     72308
# 0     69638
# 7     59133
# 1     47426
# 17    40043
# 20    33562
# 12    31179
# 14    27309
# 2     26588
# 16    25371
# 6     20355
# 3     17650
# 10    12930
# 5     12177
# 15    12165
# 11    11586
# 19     8461
# 13     7728
# 18     6622
# 9      6291
# 8      1546
# Name: count, dtype: int64

# %%
df.groupby("Occupation").ngroups
# Out:
# 21

# %% [raw]
# Analysis:
# -->20 different types of occupations are recorded in the Dataset and no records of occupation is 69638

# %%
'''
Univariate Analysis
'''

# %%
df.head()
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
# 2  1000001  P00087842      F  0-17          10             A
# 3  1000001  P00085442      F  0-17          10             A
# 4  1000002  P00285442      M   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category  Purchase
# 0                          2               0                 3      8370
# 1                          2               0                 1     15200
# 2                          2               0                12      1422
# 3                          2               0                12      1057
# 4                         4+               0                 8      7969

# %% [raw]
# Analysis with Categorical Variables

# %% [raw]
# Product_ID

# %%
plt.figure(figsize=(20,8))
sns.countplot(data = df,x="Product_ID")
# Out:
# <Axes: xlabel='Product_ID', ylabel='count'>

# %%
df["Product_ID"].value_counts()
# Out:
# Product_ID
# P00265242    1880
# P00025442    1615
# P00110742    1612
# P00112142    1562
# P00057642    1470
#              ...
# P00314842       1
# P00298842       1
# P00231642       1
# P00204442       1
# P00066342       1
# Name: count, Length: 3631, dtype: int64

# %% [raw]
# Analysis for Product_ID:
#     ---> As we can see Product ID P00265242 is having the highest count of 1880

# %% [raw]
# Age

# %%
plt.figure(figsize=(20,8))
sns.countplot(data = df,x="Age")
# Out:
# <Axes: xlabel='Age', ylabel='count'>

# %% [raw]
# Analysis:
#     --> We can see that the Age group between 26-35 is having the highest count

# %% [raw]
# Product Category

# %%
plt.figure(figsize=(20,8))
sns.countplot(data = df,x="Product_Category")
# Out:
# <Axes: xlabel='Product_Category', ylabel='count'>

# %% [raw]
# Analysis:
#     --> Product category 5, 1 and 8 are the top three category customers preferred most.

# %% [raw]
# Marital Status

# %%
plt.figure(figsize=(20,8))
sns.countplot(data = df,x="Marital_Status")
# Out:
# <Axes: xlabel='Marital_Status', ylabel='count'>

# %% [raw]
# Analysis:
#     --> Unmarried customers are in the highest numbers

# %% [raw]
# City Category

# %%
plt.figure(figsize=(20,8))
sns.countplot(data = df,x="City_Category")
# Out:
# <Axes: xlabel='City_Category', ylabel='count'>

# %% [raw]
# Analysis:
#     --> Customers from City B are in highest numbers than the other 2 cities.

# %% [raw]
# Occupation

# %%
plt.figure(figsize=(20,8))
sns.countplot(data = df,x="Occupation")
plt.xticks(rotation=90,fontsize = 8)
plt.yticks(fontsize = 8)
plt.xlabel("Occupation Category")
plt.ylabel("Count in each Category")
plt.show()

# %% [raw]
# Analysis:
#     --> Customers with occupation category 4,0 and 7 is in high numbers

# %% [raw]
# Stay In Current City (No.Of.Years)

# %%
plt.figure(figsize=(20,8))
sns.countplot(data = df,x="Stay_In_Current_City_Years")
# Out:
# <Axes: xlabel='Stay_In_Current_City_Years', ylabel='count'>

# %% [raw]
# Analysis:
#     --> Customers who stay in the city for 1 year is higher

# %% [raw]
# Univariate Analysis using numerical variable

# %% [raw]
# Purchase

# %%
plt.figure(figsize=(20,8))
sns.displot(data = df,x="Purchase",kde = True)
# Out:
# C:\Users\Chitra\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [raw]
# Analysis:
#     --> In the above distribution, we can see most of the purchase is made between 5000 - 10000

# %% [raw]
# Outlier Detection:

# %%
plt.figure(figsize=(20,8))
sns.boxplot(data = df,x="Purchase")
# Out:
# <Axes: xlabel='Purchase'>

# %% [raw]
# Analysis:
#     --> Maximum purchases customer makes is nearly 20000
#     --> 50% of the transaction is less than 10000 and 75 % is less than 12000

# %%
plt.figure(figsize=(20,8))
sns.boxplot(data = df,x="Product_Category")
# Out:
# <Axes: xlabel='Product_Category'>

# %% [raw]
# Analysis:
#     --> 50% of Product category prefferred is 5 and below
#     --> Product Category 20 is very rarely preferred as we can see few outliers

# %% [raw]
# Bi-Variate Analysis

# %%
plt.figure(figsize=(20,15))

plt.subplot(3,2,1)
sns.boxplot(data = df,x="Gender",y="Purchase")
plt.title("Gender vs Purchase",fontsize=10)

plt.subplot(3,2,2)
sns.boxplot(data = df,x="City_Category",y="Purchase")
plt.title("City_Category vs Purchase",fontsize=10)

plt.subplot(3,2,3)
sns.boxplot(data = df,x="Product_Category",y="Purchase")
plt.title("Product_Category vs Purchase",fontsize=10)

plt.subplot(3,2,4)
sns.boxplot(data = df,x="Stay_In_Current_City_Years",y="Purchase")
plt.title("Stay_In_Current_City_Years vs Purchase",fontsize=10)

plt.subplot(3,2,5)
sns.boxplot(data = df,x="Age",y="Purchase")
plt.title("Age vs Purchase",fontsize=10)

plt.subplot(3,2,6)
sns.boxplot(data = df,x="Marital_Status",y="Purchase")
plt.title("Marital_Status vs Purchase",fontsize=10)
# Out:
# Text(0.5, 1.0, 'Marital_Status vs Purchase')

# %% [raw]
# Bi-Variate Analysis:
#     --> Male customers max purchase is greater than Female customers maximum purchase
#     --> Customers from City C is making more purchases than other two cities.
#     --> Unmarried customers make more purchases than Married customers
#     --> Customers between all the Age group makes more purchases except for 55+ group with few outliers.

# %%
sns.boxplot(data = df,x="Occupation",y="Purchase")
plt.title("Occupation vs Purchase",fontsize=10)
# Out:
# Text(0.5, 1.0, 'Occupation vs Purchase')

# %% [raw]
# Multi-Variate Analysis

# %%
plt.figure(figsize=(20,15))

plt.subplot(2,2,1)
sns.boxplot(data = df,x="Gender",y="Purchase",hue = "Age")
plt.title("Gender vs Purchase",fontsize=10)

plt.subplot(2,2,2)
sns.boxplot(data = df,x="City_Category",y="Purchase",hue = "Gender")
plt.title("City_Category vs Purchase",fontsize=10)

plt.subplot(2,2,3)
sns.boxplot(data = df,x="Stay_In_Current_City_Years",y="Purchase",hue = "Gender")
plt.title("Stay_In_Current_City_Years vs Purchase",fontsize=10)

plt.subplot(2,2,4)
sns.boxplot(data = df,x="Marital_Status",y="Purchase",hue = "Gender")
plt.title("Marital_Status vs Purchase",fontsize=10)
# Out:
# Text(0.5, 1.0, 'Marital_Status vs Purchase')

# %% [raw]
# Multi-Variate Analysis:
#     -->Female customers in Age group 55+ makes less purchase than Female customers in other Age groups.
#     -->Male customer purchases are higher in Age group between 18- 25 and 51-55.
#     -->Male customers from City C is making more Purchases.
#     -->Male customers who stays in same city for 2 - 3 years are making higher purchases
#     --> Male customers both Married and Unmarried are making more purchases than female customers

# %%
plt.figure(figsize=(20,8))

sns.boxplot(data = df,x="Product_Category",y="Purchase",hue = "Gender")
plt.title("Product_Category vs Purchase",fontsize=10)
# Out:
# Text(0.5, 1.0, 'Product_Category vs Purchase')

# %%
df_new= df

# %%
df_new["Product_Category"]=df_new["Product_Category"].astype('object')

# %%
df_new.head()
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
# 2  1000001  P00087842      F  0-17          10             A
# 3  1000001  P00085442      F  0-17          10             A
# 4  1000002  P00285442      M   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status Product_Category  Purchase
# 0                          2               0                3      8370
# 1                          2               0                1     15200
# 2                          2               0               12      1422
# 3                          2               0               12      1057
# 4                         4+               0                8      7969

# %%
df_new["Product_Category"].value_counts()
# Out:
# Product_Category
# 5     150933
# 1     140378
# 8     113925
# 11     24287
# 2      23864
# 6      20466
# 3      20213
# 4      11753
# 16      9828
# 15      6290
# 13      5549
# 10      5125
# 12      3947
# 7       3721
# 18      3125
# 20      2550
# 19      1603
# 14      1523
# 17       578
# 9        410
# Name: count, dtype: int64

# %%
plt.figure(figsize=(20,8))
sns.boxplot(data = df_new,x="Age",y="Product_Category",hue = "Gender")
plt.title("Product_Category vs Age_Group",fontsize=10)
# Out:
# Text(0.5, 1.0, 'Product_Category vs Age_Group')

# %% [raw]
# Analysis:
#     ---> Median is almost same in every Age groups
#     ---> 55+ Agegroup Female is having lost of outliers
#     ---> 75 % of purchases made in Product_Category between 2-8

# %%
df.head()
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
# 2  1000001  P00087842      F  0-17          10             A
# 3  1000001  P00085442      F  0-17          10             A
# 4  1000002  P00285442      M   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status Product_Category  Purchase
# 0                          2               0                3      8370
# 1                          2               0                1     15200
# 2                          2               0               12      1422
# 3                          2               0               12      1057
# 4                         4+               0                8      7969

# %% [raw]
# Average amount spent by Male vs Female:

# %%
df[df["Gender"]=='F']["Purchase"].mean()
# Out:
# 8734.565765155476

# %%
df[df["Gender"]=='M']["Purchase"].mean()
# Out:
# 9437.526040472265

# %%
plt.figure(figsize=(20,8))
sns.barplot(data = df_new,x="Gender",y="Purchase",hue = "Age")
plt.title("Purchase vs Gender",fontsize=10)
# Out:
# Text(0.5, 1.0, 'Purchase vs Gender')

# %% [raw]
# Analysis:
#     --> Male customers purchased more than Female customers in almost all the Age groups.

# %% [raw]
# CLT with Gender and Purchase:

# %% [raw]
# Population Mean of Male and Female Customer

# %%
pop_mean_m = df[df["Gender"]=='M']["Purchase"].mean()

# %%
pop_mean_f= df[df["Gender"]=='F']["Purchase"].mean()

# %%
pop_sd_m = df[df["Gender"]=='M']["Purchase"].std()

# %%
pop_sd_f = df[df["Gender"]=='F']["Purchase"].std()

# %% [raw]
# Sample mean of Male and Female Customers

# %%
df_Purchase_M = df[df["Gender"]=='M']["Purchase"]

# %%
df_Purchase_M.head()
# Out:
# 4     7969
# 5    15227
# 6    19215
# 7    15854
# 8    15686
# Name: Purchase, dtype: int64

# %%
df_Purchase_F = df[df["Gender"]=='F']["Purchase"]

# %%
df_Purchase_F.head()
# Out:
# 0      8370
# 1     15200
# 2      1422
# 3      1057
# 14     5378
# Name: Purchase, dtype: int64

# %%
len(df_Purchase_M)
# Out:
# 414259

# %%
import random

# %%
male_mean_dist = [np.mean(random.sample(df_Purchase_M.to_list(), 1000)) for i in range(1000)]

# %%
female_mean_dist = [np.mean(random.sample(df_Purchase_F.to_list(), 1000)) for i in range(1000)]

# %%
M_s_mean = np.mean(random.sample(df_Purchase_M.to_list(), 1000))

# %%
F_s_mean = np.mean(random.sample(df_Purchase_F.to_list(), 1000))

# %%
M_s_std = np.std(random.sample(df_Purchase_M.to_list(), 1000))

# %%
F_s_std = np.std(random.sample(df_Purchase_F.to_list(), 1000))

# %%
sns.histplot(male_mean_val,kde = True)
sns.histplot(female_mean_val,kde=True)
# Out:
# <Axes: ylabel='Count'>

# %%
np.mean(male_mean_val)
# Out:
# 9442.402876

# %%
np.mean(female_mean_val)
# Out:
# 8727.190973

# %%
print(f"Population_mean_Male: {pop_mean_m} Population_std_Male: {pop_sd_m}")
# Out:
# Population_mean_Male: 9437.526040472265 Population_std_Male: 5092.186209777949

# %%
print(f"Population_mean_Female: {pop_mean_f} Population_std_Female: {pop_sd_f}")
# Out:
# Population_mean_Female: 8734.565765155476 Population_std_Female: 4767.233289291444

# %%
print(f"Sample_mean_Male: {M_s_mean} Sample_std_Male: {M_s_std}")
# Out:
# Sample_mean_Male: 9573.127 Sample_std_Male: 5193.937101297627

# %%
print(f"Sample_mean_Female: {F_s_mean} Sample_std_Female: {F_s_std}")
# Out:
# Sample_mean_Female: 8723.231 Sample_std_Female: 4928.098952283731

# %% [raw]
# CLT with Age and Purchase:

# %% [raw]
# Population mean and SD

# %%
pop_mean_Age = df[df["Gender"]=='M']["Purchase"].mean()

# %%
df["Age"].value_counts()
# Out:
# Age
# 26-35    219587
# 36-45    110013
# 18-25     99660
# 46-50     45701
# 51-55     38501
# 55+       21504
# 0-17      15102
# Name: count, dtype: int64

# %%
all_means={}
age_intervals = df["Age"].value_counts().index
for age_interval in age_intervals:
    all_means[age_interval] = []

# %%
age_intervals
# Out:
# Index(['26-35', '36-45', '18-25', '46-50', '51-55', '55+', '0-17'], dtype='object', name='Age')

# %%
all_means
# Out:
# {'26-35': [],
#  '36-45': [],
#  '18-25': [],
#  '46-50': [],
#  '51-55': [],
#  '55+': [],
#  '0-17': []}

# %%
all_means['26-35']=[np.mean(random.sample(df[df["Age"]=='26-35']["Purchase"].to_list(), 100)) for i in range(1000)]

# %%
type(all_means)
# Out:
# dict

# %%
len(all_means)
# Out:
# 7

# %%
all_means['36-45']=[np.mean(random.sample(df[df["Age"]=='36-45']["Purchase"].to_list(), 100)) for i in range(1000)]

# %%
all_means['18-25']=[np.mean(random.sample(df[df["Age"]=='18-25']["Purchase"].to_list(), 100)) for i in range(1000)]

# %%
all_means['46-50']=[np.mean(random.sample(df[df["Age"]=='46-50']["Purchase"].to_list(), 100)) for i in range(1000)]
all_means['51-55']=[np.mean(random.sample(df[df["Age"]=='51-55']["Purchase"].to_list(), 100)) for i in range(1000)]
all_means['55+']=[np.mean(random.sample(df[df["Age"]=='55+']["Purchase"].to_list(), 100)) for i in range(1000)]
all_means['0-17']=[np.mean(random.sample(df[df["Age"]=='0-17']["Purchase"].to_list(), 100)) for i in range(1000)]

# %%
plt.figure(figsize=(20,15))

plt.subplot(3,3,1)
sns.histplot(all_means[age_intervals[0]],kde=True)
plt.title(f"Age_Group: {age_intervals[0]}",fontsize=10)

plt.subplot(3,3,2)
sns.histplot(all_means[age_intervals[1]],kde=True)
plt.title(f"Age_Group: {age_intervals[1]}",fontsize=10)

plt.subplot(3,3,3)
sns.histplot(all_means[age_intervals[2]],kde=True)
plt.title(f"Age_Group: {age_intervals[2]}",fontsize=10)

plt.subplot(3,3,4)
sns.histplot(all_means[age_intervals[3]],kde=True)
plt.title(f"Age_Group: {age_intervals[3]}",fontsize=10)

plt.subplot(3,3,5)
sns.histplot(all_means[age_intervals[4]],kde=True)
plt.title(f"Age_Group: {age_intervals[4]}",fontsize=10)

plt.subplot(3,3,6)
sns.histplot(all_means[age_intervals[5]],kde=True)
plt.title(f"Age_Group: {age_intervals[5]}",fontsize=10)

plt.subplot(3,3,7)
sns.histplot(all_means[age_intervals[6]],kde=True)
plt.title(f"Age_Group: {age_intervals[6]}",fontsize=10)
# Out:
# Text(0.5, 1.0, 'Age_Group: 0-17')

# %% [raw]
# CLT with Married and Unmarried Customers:

# %% [raw]
# Sample mean and SD:

# %%
df_Married = df[df["Marital_Status"]==1]["Purchase"]

# %%
df_Unmarried = df[df["Marital_Status"]==0]["Purchase"]

# %%
Married_mean_dist = [np.mean(random.sample(df_Married.to_list(), 1000)) for i in range(1000)]

# %%
Unmarried_mean_dist = [np.mean(random.sample(df_Unmarried.to_list(), 1000)) for i in range(1000)]

# %%
Married_dist = [random.sample(df_Married.to_list(), 1000) for i in range(1000)]
s_m_M = np.mean(Married_dist)

# %%
s_sd_M = np.std(Married_dist)

# %%
Unmarried_dist = [random.sample(df_Unmarried.to_list(), 1000) for i in range(1000)]
s_m_UM = np.mean(Unmarried_dist)

# %%
s_sd_UM = np.std(Unmarried_dist)

# %%
pop_mean_M= np.mean(df_Married)

# %%
pop_mean_UM = np.mean(df_Unmarried)

# %%
pop_std_M= np.std(df_Married)

# %%
pop_std_UM= np.std(df_Unmarried)

# %%
sns.histplot(Married_mean_dist,kde=True)
sns.histplot(Unmarried_mean_dist,kde=True)
# Out:
# <Axes: ylabel='Count'>

# %%
print(f"Pop mean of Married: {pop_mean_M} and Pop SD of Married: {pop_std_M}")
# Out:
# Pop mean of Married: 9261.174574082374 and Pop SD of Married: 5016.886245793184

# %%
print(f"Sample mean of Married: {s_m_M} and Sample SD of Married: {s_sd_M}")
# Out:
# Sample mean of Married: 9255.924836 and Sample SD of Married: 5017.091722732443

# %%
print(f"Pop mean of Unmarried: {pop_mean_UM} and Pop SD of Unmarried: {pop_std_UM}")
# Out:
# Pop mean of Unmarried: 9265.907618921507 and Pop SD of Unmarried: 5027.340117880186

# %%
print(f"Sample mean of Unmarried: {s_m_UM} and Sample SD of Unmarried: {s_sd_UM}")
# Out:
# Sample mean of Unmarried: 9269.490203 and Sample SD of Unmarried: 5036.7509112422895

# %% [raw]
# Confidence Interval

# %% [raw]
# CI for Gender:

# %%
SE_M =pop_sd_m/np.sqrt(1000)


[M_s_mean-1.96*SE_M, M_s_mean+1.96*SE_M]
# Out:
# [9257.510028825074, 9888.743971174927]

# %% [raw]
# Analysis:
#
# 95% of the times, the sample purchase amount average for the males happen to be between 9257 to 9888

# %%
SE_F =pop_sd_f/np.sqrt(1000)


[F_s_mean-1.96*SE_F, F_s_mean+1.96*SE_F]
# Out:
# [8427.754819501868, 9018.707180498131]

# %% [raw]
# Analysis:
#
# 95% of the times, the sample purchase amount average for the males happen to be between 8427 to 9018

# %% [raw]
# CI for Marital Status:

# %%
SE_M =pop_std_M/np.sqrt(1000)


[s_m_M-1.96*SE_M, s_m_M+1.96*SE_M]
# Out:
# [8944.975004945916, 9566.874667054084]

# %% [raw]
# Analysis:
#
# 95% of the times, the sample purchase amount average for the Married customer happen to be between 8944 to 9566

# %%
SE_F =pop_std_UM/np.sqrt(1000)


[s_m_UM-1.96*SE_F, s_m_UM+1.96*SE_F]
# Out:
# [8957.89243424112, 9581.08797175888]

# %% [raw]
# Analysis:
#
# 95% of the times, the sample purchase amount average for the Unmarried customer happen to be between 8957 to 9581

# %% [raw]
# CI for Age groups:

# %%
ag={}

# %%
len(age_intervals)
# Out:
# 7

# %%
for i in range(len(age_intervals)):
    ag[age_intervals[i]] = np.mean(all_means[age_intervals[i]])
print(ag)
# Out:
# {'26-35': 9256.7613, '36-45': 9353.2438, '18-25': 9153.620309999998, '46-50': 9212.047789999999, '51-55': 9495.84287, '55+': 9314.93961, '0-17': 8927.81675}

# %%
age_group[age_intervals[0]]= np.mean(all_means[age_intervals[0]])
age_group[age_intervals[1]]= np.mean(all_means[age_intervals[1]])
age_group[age_intervals[2]]= np.mean(all_means[age_intervals[2]])
age_group[age_intervals[3]]= np.mean(all_means[age_intervals[3]])
age_group[age_intervals[4]]= np.mean(all_means[age_intervals[4]])
age_group[age_intervals[5]]= np.mean(all_means[age_intervals[5]])
age_group[age_intervals[6]]= np.mean(all_means[age_intervals[6]])

# %%
age_group
# Out:
# {'26-35': 9256.7613,
#  '36-45': 9353.2438,
#  '18-25': 9153.620309999998,
#  '46-50': 9212.047789999999,
#  '51-55': 9495.84287,
#  '55+': 9314.93961,
#  '0-17': 8927.81675}

# %%
SD ={}
for i in range(len(age_intervals)):
    SD[i] = df[df["Age"]==age_intervals[i]]["Purchase"].std()

# %%
SD
# Out:
# {0: 5010.527303002927,
#  1: 5022.923879204652,
#  2: 5034.321997176577,
#  3: 4967.216367142921,
#  4: 5087.368079602116,
#  5: 5011.493995603418,
#  6: 5111.11404600277}

# %% [raw]
# print(f"95 % of times, Age group {age_intervals[0]} spends average amount between {[age_group[age_intervals[0]]-1.96*(SD[0]/np.sqrt(1000))]}")

# %%
print(f"{age_intervals[0]}: {[age_group[age_intervals[0]]-1.96*(SD[0]/np.sqrt(1000))]}, {[age_group[age_intervals[0]]+1.96*(SD[0]/np.sqrt(1000))]}")
# Out:
# 26-35: [8946.205600303383], [9567.316999696617]

# %% [raw]
# Analysis:
#
# 95% of the times, the sample purchase amount average for the customer between Age group 26-35 happen to be between 8946 to 9567

# %%
print(f"{age_intervals[1]}: {[age_group[age_intervals[1]]-1.96*(SD[1]/np.sqrt(1000))]}, {[age_group[age_intervals[1]]+1.96*(SD[1]/np.sqrt(1000))]}")
# Out:
# 36-45: [9041.919752550071], [9664.56784744993]

# %% [raw]
# Analysis:
#
# 95% of the times, the sample purchase amount average for the customer between Age group 36-45 happen to be between 9041 to 9664

# %%
print(f"{age_intervals[2]}: {[age_group[age_intervals[2]]-1.96*(SD[2]/np.sqrt(1000))]}, {[age_group[age_intervals[2]]+1.96*(SD[2]/np.sqrt(1000))]}")
# Out:
# 18-25: [8841.58979987899], [9465.650820121007]

# %% [raw]
# Analysis:
#
# 95% of the times, the sample purchase amount average for the customer between Age group 18-25 happen to be between 8841 to 9465

# %%
print(f"{age_intervals[3]}: {[age_group[age_intervals[3]]-1.96*(SD[3]/np.sqrt(1000))]}, {[age_group[age_intervals[3]]+1.96*(SD[3]/np.sqrt(1000))]}")
# Out:
# 46-50: [8904.176529919638], [9519.91905008036]

# %% [raw]
# Analysis:
#
# 95% of the times, the sample purchase amount average for the customer between Age group 46-50 happen to be between 8904 to 9519

# %%
print(f"{age_intervals[4]}: {[age_group[age_intervals[4]]-1.96*(SD[4]/np.sqrt(1000))]}, {[age_group[age_intervals[4]]+1.96*(SD[4]/np.sqrt(1000))]}")
# Out:
# 51-55: [9180.524529627282], [9811.161210372718]

# %% [raw]
# Analysis:
#
# 95% of the times, the sample purchase amount average for the customer between Age group 51-55 happen to be between 9180 to 9811

# %%
print(f"{age_intervals[5]}: {[age_group[age_intervals[5]]-1.96*(SD[5]/np.sqrt(1000))]}, {[age_group[age_intervals[5]]+1.96*(SD[5]/np.sqrt(1000))]}")
# Out:
# 55+: [9004.323994075252], [9625.555225924747]

# %% [raw]
# Analysis:
#
# 95% of the times, the sample purchase amount average for the customer between Age group 55+ happen to be between 9004 to 9625

# %%
print(f"{age_intervals[6]}: {[age_group[age_intervals[6]]-1.96*(SD[6]/np.sqrt(1000))]}, {[age_group[age_intervals[6]]+1.96*(SD[6]/np.sqrt(1000))]}")
# Out:
# 0-17: [8611.026619381551], [9244.606880618448]

# %% [raw]
# Analysis:
#
# 95% of the times, the sample purchase amount average for the customer between Age group 0-17 happen to be between 8611 to 9244

# %% [raw]
# Recommendations:

# %% [raw]
# Male customer purchases are higher in Age group between 18- 25 and 51-55. Company can provide offers to attract customers between these groups.
# Unmarried customers make more purchases than Married customers. Company can focus on selling products that attracts Unmarried customers.
# Product category 5, 1 and 8 are the top three category customers preferred most. Company can focus on selling these product.
# Male customers from City C is making more purchases than other two cities. Company can bring more offline store offers and special stalls in City C to increase the revenue.
# Male customers who stays in same city for 2 - 3 years are making higher purchases. Company can provide special discounts to customer who is regular for 2 - 3 years.
